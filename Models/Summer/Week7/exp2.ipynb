# %% [markdown]
# ### What is the requirement
# - We have initial inventory
# - And semi-constant demand
# - So inventory keeps reducing towards 0 at each timestep
# - Before it reaches zero, we want the time steps it might take to reach it
# - and then

# %%
iL = 1000
D = 100
L = 2
while (iL - (D*L)) > 0:
    iL -= D
    print(iL)
print("Place an order!")
from scipy.stats import norm

# %%
from scipy.stats import norm
import numpy as np
import math 
D = 1000
S = 100
H = 0.3
Q = math.sqrt((2*D*S)/H)
L = 2
iL = 10000
for cycle in range(12):
    demand  = int(500+80*np.random.randn(1))
    if iL - (demand*L) > 0:
        iL -= demand
# Out:
# 9659
# 9318
# 8977
# 8636
# 8295
# 7954
# 7613
# 7272
# 6931
# 6590
# 6249
# 5908
# 5567
# 5226
# 4885
# 4544
# 4203
# 3862
# 3521
# 3180
# 2839
# 2498
# 2157
# 1816
# 1475
# 1134
# 793
# 452
# 776.496580927726
# 1186.993161855452
# 780.993161855452
# 1207.489742783178
# 817.4897427831779
# 427.4897427831779
# 711.9863237109039
# 1108.4829046386299
# 688.4829046386299
# 1065.9794855663558
# 626.9794855663558
# 943.4760664940818
# 1320.9726474218078
# 881.9726474218078
# 442.9726474218078
# 698.4692283495338
# 1038.9658092772597
# 562.9658092772597
# 813.4623902049857
