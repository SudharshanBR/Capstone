# %% [markdown]
# ## MCMC Testing on Intel Data - scrapped due to parameter limits issue.

# %%
import numpy as np
import pandas as pd
import scipy.optimize
from pymcmcstat.MCMC import MCMC
import matplotlib.pyplot as plt
import pymcmcstat
print(pymcmcstat.__version__)
# Out:
# 1.9.1

# %%
mcstat = MCMC()

# %%
dataframe = pd.read_csv('../Datasets/IntelData.csv')
newDF = dataframe[['Week','Forecasted Demand','Customer Orders']].copy(deep=True)
allForecasts = newDF.groupby('Week')['Forecasted Demand'].mean()
allCOs = newDF.groupby('Week')['Customer Orders'].mean()
newDF = allForecasts.to_frame(name='Forecasts')
newDF['COs'] = allCOs
newDF
# Out:
#          Forecasts           COs
# Week
# 1     63641.381443  14143.072165
# 2     63660.948980  15053.602041
# 3     73899.152941  18662.976471
# 4     79106.714286  16715.964286
# 5     74011.863158  26580.926316
# ...            ...           ...
# 183   31936.617284  10061.413580
# 184   28333.934641  12077.431373
# 185   24904.424242  11460.230303
# 186   32661.811321  12828.861635
# 187   34166.417808  16293.691781
#
# [187 rows x 2 columns]

# %%
ndp = 187
x = newDF.index.values
y = newDF['COs'].to_numpy()

# %%
print(x.shape)
# Out:
# (187,)

# %%
x = x.reshape(ndp, 1)
y = y.reshape(ndp, 1)

# %%
mcstat.data.add_data_set(x,y)

# %%
mcstat.data.n.append(len(newDF.index))
print(mcstat.data.n[0], y.shape)
# Out:
# 187 (187, 1)

# %%
def modelfun(x, theta):
    return theta[0]*x/(theta[1] + x)

def ssfun(theta,data):
    res = data.ydata[0] - modelfun(data.xdata[0], theta)
    return (res ** 2).sum(axis=0)

# %%
print(mcstat.data.ydata[0].shape)
# Out:
# (187, 1)

# %%
def residuals(p, x, y):
    return y - modelfun(x, p)

theta0, ssmin = scipy.optimize.leastsq(residuals, x0=[0,10], args=(mcstat.data.xdata[0].reshape(ndp,), mcstat.data.ydata[0].reshape(ndp,))) ## ISSUE STARTS HERE WITH x0 - the initial assumption
print(theta0, ssmin)
n = mcstat.data.n[0] # number of data points in model
p = len(theta0); # number of model parameters (dof)
ssmin = ssfun(theta0, mcstat.data) # calculate the sum-of-squares error
mse = ssmin/(n-p) # estimate for the error variance
# Out:
# [ 0.14541946 49.05264353] 1

# %%
J = np.array([[x/(theta0[1]+x)], [-theta0[0]*x/(theta0[1]+x)**2]])
J = J.transpose()
J = J.reshape(n,p)
tcov = np.linalg.inv(np.dot(J.transpose(), J))*mse
print('tcov = {}'.format(tcov))
# Out:
# tcov = [[2.44704292e-04 2.50111372e-01]
#  [2.50111372e-01 3.20831762e+02]]

# %%
theta0[0]
# Out:
# 0.14541945985989266

# %%
theta0[1]
# Out:
# 49.052643528805845

# %%
mcstat.parameters.add_model_parameter(
    name='$\mu_{max}$',
    theta0=theta0[0],
    )
mcstat.parameters.add_model_parameter(
    name='$K_x$',
    theta0=theta0[1],
    )

# %%
mcstat.simulation_options.define_simulation_options(
    nsimu=5.0e3,
    updatesigma=1,
    qcov=tcov)
mcstat.model_settings.define_model_settings(
    sos_function=ssfun,
    sigma2=0.01**2)

# %%
mcstat.run_simulation()
# Out:
# Sampling these parameters:
#       name      start [      min,       max] N(       mu,   sigma^2)
# $\mu_{max}$:      0.15 [ 0.00e+00,       inf] N( 0.00e+00,      inf)
#      $K_x$:     49.05 [ 0.00e+00,       inf] N( 0.00e+00,      inf)
# $\mu_{max}$:      0.15 [     -inf,       inf] N( 0.00e+00,      inf)
#      $K_x$:     49.05 [     -inf,       inf] N( 0.00e+00,      inf)
# $\mu_{max}$:      0.15 [     -inf,       inf] N( 0.00e+00,      inf)
#      $K_x$:     49.05 [     -inf,       inf] N( 0.00e+00,      inf)
# $\mu_{max}$:      0.15 [     -inf,       inf] N( 0.00e+00,      inf)
#      $K_x$:     49.05 [     -inf,       inf] N( 0.00e+00,      inf)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 mcstat.run_simulation()
#
# File ~\Anaconda3\lib\site-packages\pymcmcstat\MCMC.py:98, in MCMC.run_simulation(self, use_previous_results)
#      85 '''
#      86 Run MCMC Simulation
#      87
#    (...)
#      95     * **use_previous_results** (:py:class:`bool`): Flag to indicate whether simulation is being restarted.
#      96 '''
#      97 start_time = time.time()
# ---> 98 self.__setup_simulator(use_previous_results=use_previous_results)
#      99 # ---------------------
#     100 # setup progress bar
#     101 if self.simulation_options.waitbar:
#
# File ~\Anaconda3\lib\site-packages\pymcmcstat\MCMC.py:162, in MCMC.__setup_simulator(self, use_previous_results)
#     159     self.simulation_options.qcov = np.array(res['qcov'])
#     161 self.__chain_index = 0  # start index at zero
# --> 162 self._initialize_simulation()
#     163 self.__initialize_chains(
#     164         chainind=self.__chain_index,
#     165         nsimu=self.simulation_options.nsimu,
#    (...)
#     168         updatesigma=self.simulation_options.updatesigma,
#     169         sigma2=self.model_settings.sigma2)
#
# File ~\Anaconda3\lib\site-packages\pymcmcstat\MCMC.py:191, in MCMC._initialize_simulation(self)
#     189 self.parameters.display_parameter_settings(self.simulation_options.verbosity, self.parameters._no_adapt)
#     190 # setup covariance matrix and initial Cholesky decomposition
# --> 191 self._covariance._initialize_covariance_settings(self.parameters, self.simulation_options)
#     192 # ---------------------
#     193 # define sum-of-squares object
#     194 self.__sos_object = SumOfSquares(self.model_settings, self.data, self.parameters)
#
# File ~\Anaconda3\lib\site-packages\pymcmcstat\procedures\CovarianceProcedures.py:56, in CovarianceProcedures._initialize_covariance_settings(self, parameters, options)
#      53 self.__check_adascale(options.adascale, parameters.npar)
#      54 # ----------------
#      55 # setup R matrix (R used to update in metropolis)
# ---> 56 self.__setup_R_matrix(parameters._parind)
#      57 # ----------------
#      58 # setup RDR matrix (RDR used in DR)
#      59 if options.method == 'dram' or options.method == 'dr':
#
# File ~\Anaconda3\lib\site-packages\pymcmcstat\procedures\CovarianceProcedures.py:152, in CovarianceProcedures.__setup_R_matrix(self, parind)
#     150     self.__setup_R_based_on_variances(parind)
#     151 else:  # qcov has covariance matrix in it
# --> 152     self.__setup_R_based_on_covariance_matrix(parind)
#
# File ~\Anaconda3\lib\site-packages\pymcmcstat\procedures\CovarianceProcedures.py:163, in CovarianceProcedures.__setup_R_based_on_covariance_matrix(self, parind)
#     161 def __setup_R_based_on_covariance_matrix(self, parind):
#     162     self._qcovorig = np.copy(self._qcov)  # save qcov
# --> 163     self._qcov = self._qcov[np.ix_(parind, parind)]  # this operation in matlab maintains matrix (debug)
#     164     if self._qcov.size == 1:
#     165         self._R = np.sqrt(self._qcov)
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
results = mcstat.simulation_results.results
names = results['names']
chain = results['chain']
s2chain = results['s2chain']
names = results['names'] # parameter names
mcstat.chainstats(chain, results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 results = mcstat.simulation_results.results
#       2 names = results['names']
#       3 chain = results['chain']
#
# AttributeError: 'MCMC' object has no attribute 'simulation_results'

# %%
### Simulation does not run due to parameter limits
# Not sure what to change.
# EOF.

# %% [markdown]
# ## Running exact MCMC from https://nbviewer.org/github/prmiles/pymcmcstat_examples/blob/master/Monod.ipynb

# %%
import numpy as np
import scipy.optimize
from pymcmcstat.MCMC import MCMC
import matplotlib.pyplot as plt
import pymcmcstat
print(pymcmcstat.__version__)
# Out:
# 1.9.1

# %%
# Initialize MCMC object
mcstat = MCMC()
# Next, create a data structure for the observations and control
# variables. Typically one could make a structure |data| that
# contains fields |xdata| and |ydata|.
ndp = 7
x = np.array([28, 55, 83, 110, 138, 225, 375])  # (mg / L COD)
x = x.reshape(ndp, 1) # enforce column vector
y = np.array([0.053, 0.060, 0.112, 0.105, 0.099, 0.122, 0.125]) # (1 / h)
y = y.reshape(ndp, 1) # enforce column vector
# data structure 
mcstat.data.add_data_set(x,y)

# %%
def modelfun(x, theta):
    return theta[0]*x/(theta[1] + x)

def ssfun(theta,data):
    res = data.ydata[0] - modelfun(data.xdata[0], theta)
    return (res ** 2).sum(axis=0)

# %%
def residuals(p, x, y):
    return y - modelfun(x, p)

theta0, ssmin = scipy.optimize.leastsq(
    residuals,
    x0=[0.15, 100],
    args=(mcstat.data.xdata[0].reshape(ndp,),
          mcstat.data.ydata[0].reshape(ndp,)))
n = mcstat.data.n[0] # number of data points in model
p = len(theta0); # number of model parameters (dof)
ssmin = ssfun(theta0, mcstat.data) # calculate the sum-of-squares error
mse = ssmin/(n-p) # estimate for the error variance

# %%
J = np.array([[x/(theta0[1]+x)], [-theta0[0]*x/(theta0[1]+x)**2]])
J = J.transpose()
J = J.reshape(n,p)
tcov = np.linalg.inv(np.dot(J.transpose(), J))*mse
print('tcov = {}'.format(tcov))
# Out:
# tcov = [[2.44707212e-04 2.50115314e-01]
#  [2.50115314e-01 3.20837579e+02]]

# %%
mcstat.parameters.add_model_parameter(
    name='$\mu_{max}$',
    theta0=theta0[0],
    minimum=0)
mcstat.parameters.add_model_parameter(
    name='$K_x$',
    theta0=theta0[1],
    minimum=0)

# %%
mcstat.simulation_options.define_simulation_options(
    nsimu=5.0e3,
    updatesigma=1,
    qcov=tcov)
mcstat.model_settings.define_model_settings(
    sos_function=ssfun,
    sigma2=0.01**2)

# %%
mcstat.run_simulation()
# Out:
# Sampling these parameters:
#       name      start [      min,       max] N(       mu,   sigma^2)
# $\mu_{max}$:      0.15 [ 0.00e+00,       inf] N( 0.00e+00,      inf)
#      $K_x$:     49.05 [ 0.00e+00,       inf] N( 0.00e+00,      inf)
#  [-----------------100%-----------------] 5000 of 5000 complete in 0.6 sec

# %%
results = mcstat.simulation_results.results
names = results['names']
chain = results['chain']
s2chain = results['s2chain']
names = results['names'] # parameter names
mcstat.chainstats(chain, results)
# Out:
# ------------------------------
#       name:      mean       std    MC_err       tau    geweke
# $\mu_{max}$:  9.34e+08  4.81e+09  8.26e+08    140.93  0.00e+00
#      $K_x$:  1.73e+12  8.89e+12  1.53e+12    140.94  0.00e+00
# ------------------------------
# ==============================
# Acceptance rate information
# ---------------
# Results dictionary:
# Stage 1: 66.98%
# Stage 2: 11.86%
# Net    : 78.84% -> 3942/5000
# ---------------
# Chain provided:
# Net    : 78.84% -> 3942/5000
# ---------------
# Note, the net acceptance rate from the results dictionary
# may be different if you only provided a subset of the chain,
# e.g., removed the first part for burnin-in.
# ------------------------------

# %%
# A point estimate of the model parameters can be calculated from the
# mean of the |chain|. Here we plot the fitted model using the
# posterior means of the parameters.
xmod = np.linspace(1e-4,400)
plt.figure(1)
hmodel, = plt.plot(xmod,modelfun(xmod,np.mean(chain, 0)),
                   '-k', label='model')
hdata, = plt.plot(mcstat.data.xdata[0], mcstat.data.ydata[0],
                  's', label='data');
plt.xlim([0, 400])
plt.xlabel('x (mg/L COD)')
plt.ylabel('y (1/h)')
plt.legend(handles=[hdata, hmodel]);

# %%
from pymcmcstat import mcmcplot as mcp
# plot chain panel
mcp.plot_chain_panel(chain, names)
# The |'pairs'| options makes pairwise scatterplots of the columns of
# the |chain|.
pwfig = mcp.plot_pairwise_correlation_panel(
    chain, names, settings=dict(fig=dict(figsize=(4,4))))

# %%
def predmodelfun(data, theta):
    return modelfun(data.xdata[0], theta)

mcstat.PI.setup_prediction_interval_calculation(
    results=results,
    data=mcstat.data,
    modelfunction=predmodelfun)
mcstat.PI.generate_prediction_intervals(
    nsample=500,
    calc_pred_int=False)
# plot prediction intervals
mcstat.PI.plot_prediction_intervals(adddata=True)
plt.xlabel('x (mg/L COD)', fontsize=20)
plt.xticks(fontsize=20)
plt.ylabel('y (1/h)', fontsize=20)
plt.yticks(fontsize=20)
plt.title('Predictive envelopes of the model', fontsize=20)
# Out:
# Generating credible/prediction intervals:
#
#
# Interval generation complete
# Text(0.5, 1.0, 'Predictive envelopes of the model')

# %%
from pymcmcstat.propagation import calculate_intervals, plot_intervals

def newmodelfun(q, data):
    x = data.xdata[0]
    a, b = q
    return a*x/(b + x)

data = mcstat.data
intervals = calculate_intervals(chain, results, data, newmodelfun,
                               s2chain=s2chain, nsample=500, waitbar=True)
f, ax = plot_intervals(intervals, data.xdata[0], data.ydata[0],
               addprediction=False, adddata=True, limits=[50, 90, 95, 99])
f.tight_layout()
# Out:
#  [-----------------100%-----------------] 500 of 500 complete in 0.0 sec

# %% [markdown]
# ## OK everything runs - proceed to fixing issue.
