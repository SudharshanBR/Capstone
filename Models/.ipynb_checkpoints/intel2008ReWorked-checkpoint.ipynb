# %% [markdown]
# # Reworking a research article.

# %% [markdown]
# - Research Article : https://doi.org/10.1287/inte.1070.0339
# - Dataset Used : https://seanwillems.com/publications
# - Gist of the research article :-
#     - In 2008, Intel's planning organization discovered that their MEIO tool was generating wider than required forecast bounds.
#     - This lead to Intel holding more inventory of several SKUs than required.
#     - This in turn increases operational costs which can be avoided.
#     - The authors discovered that the incoming data to the MEIO tool was exhibiting bias and it could not be changed.
#     - Therefore, the authors came up with a way to account for that bias and change how the MEIO tool was calculating the safety stock levels.
#     - This change - resulted in reduction of operational costs significantly.
# - Goal : Recreate everything in order to understand the underlying technique to solve the safety stock estimation issue.

# %% [markdown]
# #### Importing necessary libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde as gkde
from scipy.stats import norm
import ipywidgets as widgets
# %matplotlib inline
# %matplotlib widget

# plt.style.use("default")
plt.close('all')

plt.style.use("dark_background")
plt.rcParams['figure.facecolor']=.07*np.ones(3)
plt.rcParams['figure.edgecolor']=.07*np.ones(3)
plt.rcParams['axes.facecolor']=.07*np.ones(3)  # set theme
plt.rcParams['grid.linewidth']=.2

# %% [markdown]
# #### Create the dataframe

# %%
dataframe = pd.read_csv('../Datasets/IntelData.csv')

# %%
# dataframe

# %% [markdown]
# #### Generating forecast accuracy
# - Equation 4.

# %%
dfEq4 = dataframe.copy(deep=True)
dfEq4['Theta'] = dfEq4['Forecasted Demand']/(dfEq4['Forecasted Demand'] + dfEq4['Customer Orders'])
# dfEq4

# %%
plotName = "Histogram of forecast accuracy"

if plt.fignum_exists(plotName):
    plt.close(plotName)
    
fig,ax = plt.subplots(num=plotName,figsize=(8,4))

ax.hist(dfEq4['Theta'].values,bins = 20,edgecolor='black')
ax.set_xlabel('Forecast Accuracy')
ax.set_ylabel('Count')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mu = 10
sigma = 1.2 
N = 20
M = 300
D = norm(mu,sigma)
iL = 7000
Ls = np.zeros((N+1,M))  
ns = np.arange(N+1)

# %%
Ls.shape
# Out:
# (21, 300)

# %%
ns.shape
# Out:
# (21,)

# %%
for m in range(M):
        # thisVariable = (np.random.randn(N)*sigma + mu).cumsum()
        thisVariable = D.rvs(N).cumsum()
        appendToLs = iL-thisVariable
        checkMyShape = np.r_[iL,appendToLs]
        print(checkMyShape.shape, len(checkMyShape), len(appendToLs))
        Ls[:,m] =  checkMyShape #np.r_[Lo, Lo-D.rvs(N).cumsum()]  # 
        # print(Ls.shape)
        break
# Out:
# (21,) 21 20

# %%
Ls[:,1].shape
# Out:
# (21,)

# %%
Lo = iL

# %%
with plt.ioff():
        num="MC stuff"
        if plt.fignum_exists(num):plt.close(num)
        fig,ax = plt.subplots(num=num, ncols=2, sharey=True, figsize=(12,8),
                              gridspec_kw=dict(width_ratios=[4,1], wspace=.05,top=.99,right=.99))
        ax[0].plot(ns,Ls,color="C0",alpha=.1,lw=.1,marker=".",markersize=3)

        ax[1].set(xticks=[], xlabel="PDF")
        step=N//4
        for n in np.arange(N,0,-step):
            ax[1].hist(Ls[n,:], bins = 10, density = True, orientation = "horizontal", alpha =.3, color="C0" )
        xl = ax[1].get_xlim()
        for n in np.arange(N,0,-step):
            ax[1].text(xl[1],Lo-n*mu,f"$n$={n}\n$\\mu$ = {Ls[n,:].mean():.1f}\n$\\sigma$ = {Ls[n,:].std():.1f}",ha="right",va="top")
            
        ax[0].set(xlabel="Steps $\Delta T$ ", ylabel="Inventory levels", xlim=[-1,N+1],
                  yticks=np.r_[Lo, Lo-np.arange(N,0,-step)*mu])
        fig.canvas.header_visible=False
        fig.canvas.toolbar_visible=False
        fig.canvas.show()
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
test = np.random.randn(20)
test
# Out:
# array([ 0.01814183,  0.49220568, -0.28624021,  0.1057578 ,  1.2120864 ,
#         2.61271575,  0.35570405,  1.1349757 ,  0.80505995, -0.8676906 ,
#        -0.92705232, -0.92247541, -0.47918635,  0.83633926, -0.37539861,
#         0.10397757, -0.51759626,  0.8962844 ,  0.64059867, -0.27454917])

# %%
test = test * 1.2

# %%
test = test + 10

# %%
test = test.cumsum()

# %%
test
# Out:
# array([ 10.0217702 ,  20.61241701,  30.26892876,  40.39583812,
#         51.85034179,  64.98560069,  75.41244555,  86.77441639,
#         97.74048833, 106.69925962, 115.58679683, 124.47982634,
#        133.90480272, 144.90840984, 154.45793151, 164.5827046 ,
#        173.96158909, 185.03713037, 195.80584878, 205.47638978])

# %%
test = 7000 - test
test
# Out:
# array([ 10.0217702 ,  20.61241701,  30.26892876,  40.39583812,
#         51.85034179,  64.98560069,  75.41244555,  86.77441639,
#         97.74048833, 106.69925962, 115.58679683, 124.47982634,
#        133.90480272, 144.90840984, 154.45793151, 164.5827046 ,
#        173.96158909, 185.03713037, 195.80584878, 205.47638978])

# %%
newMatrix = np.r_[7000,test]
newMatrix
# Out:
# array([7000.        , 6989.9782298 , 6979.38758299, 6969.73107124,
#        6959.60416188, 6948.14965821, 6935.01439931, 6924.58755445,
#        6913.22558361, 6902.25951167, 6893.30074038, 6884.41320317,
#        6875.52017366, 6866.09519728, 6855.09159016, 6845.54206849,
#        6835.4172954 , 6826.03841091, 6814.96286963, 6804.19415122,
#        6794.52361022])

# %%
Ls
# Out:
# array([[7000.        , 7000.        , 7000.        , ..., 7000.        ,
#         7000.        , 7000.        ],
#        [6991.67192185, 6989.5879592 , 6988.68275134, ..., 6990.15590401,
#         6992.21706555, 6987.94496988],
#        [6980.16841908, 6978.64221956, 6980.01594246, ..., 6981.66323574,
#         6982.00000006, 6978.36317143],
#        ...,
#        [6827.69963891, 6814.25640695, 6814.48123663, ..., 6825.15645834,
#         6826.17276628, 6812.79097689],
#        [6818.51687686, 6803.78928561, 6803.92595012, ..., 6815.01935954,
#         6816.2233134 , 6802.11874556],
#        [6810.28784102, 6794.53964468, 6792.50388864, ..., 6805.24933918,
#         6805.4203892 , 6792.41753185]])

# %%
type(Ls)
# Out:
# numpy.ndarray

# %%
plt.close('all')
plt.hist(Ls[1,:], bins=10,density=True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# [ 1.27051775  0.58989451  0.77604572 -1.5759813  -1.11962709 -0.19562676
#  -0.22402244  1.12748529  0.95872077  1.53075736]
# Hi
# [-2.57194583  1.68584553  1.2928323  -2.30612635 -0.17968538  0.56664809
#  -0.26965111  0.71458081 -1.28828651  0.08335756]
# Hi
# [ 0.69688593  1.24840639 -2.21828036  0.83403941 -0.58939058 -0.25247038
#   0.89160656  0.21922042 -0.51081395 -0.2035459 ]
# Hi
# [ 0.47707868 -0.10165462 -0.64661253 -0.11833376 -0.38500586 -0.99530324
#  -0.26794994  0.70814394 -0.81587303 -0.90738587]
# Hi

# %%
100 - plotMe
# Out:
# array([ 99.52292132, 100.10165462, 100.64661253, 100.11833376,
#        100.38500586, 100.99530324, 100.26794994,  99.29185606,
#        100.81587303, 100.90738587,  99.52292132,  99.62457594,
#        100.27118847, 100.38952223, 100.77452808, 101.76983133,
#        102.03778127, 101.32963733, 102.14551035, 103.05289622])

# %%
def show_demand( mu = 10, sigma=1.2, alpha_perc = 1):
    D_r = norm(mu, sigma)
    with plt.ioff():
        num="Demand distribution"
        if plt.fignum_exists(num):plt.close(num)
        fig,ax = plt.subplots(num=num)
        d_r = np.linspace(mu-4*sigma, mu+4*sigma, 100)
        
        ax.plot(d_r,D_r.pdf(d_r),color="C0")
        d_r_a = d_r[d_r<D_r.ppf(alpha_perc/100)]
        ax.fill_between(d_r_a, D_r.pdf(d_r_a),color="C0", alpha =.2)
        ax.set(xlabel="Demand rate $D_r$",ylabel="PDF",xlim=[d_r[0],d_r[-1]])
        bx = ax.twinx()
        bx.plot(d_r,D_r.cdf(d_r),color="C1")
        xl = bx.get_xlim()
        print(xl)
        bx.plot([xl[1],D_r.ppf(alpha_perc/100)], np.ones(2)*alpha_perc/100,color="C1",ls="--")
        bx.text(xl[1],alpha_perc/100,f"$\\alpha$ = {alpha_perc/100:.2f} ",ha="right",va="bottom",color="C1")
        
        bx.set(ylabel="CDF",xlim=xl)
        fig.canvas.header_visible=False
        fig.canvas.toolbar_visible=False
        fig.canvas.show()
widgets.interact(show_demand,alpha_perc=widgets.IntSlider(min=1,max=99,step=1,value=15,continuous_update=False,description = "$\\alpha$ [%]"))
# Out:
# interactive(children=(IntSlider(value=10, description='mu', max=30, min=-10), FloatSlider(value=1.2, descripti…
# <function __main__.show_demand(mu=10, sigma=1.2, alpha_perc=1)>

# %%
99/100
# Out:
# 0.99

# %%
D_r = norm(mu, sigma)
d_r = np.linspace(mu-4*sigma, mu+4*sigma, 100)
# Out:
# 100

# %%
plt.close('all')
plt.plot(D_r.pdf(d_r))
d_r_a = d_r[d_r<D_r.ppf(99/100)]
plt.fill_between(d_r_a, D_r.pdf(d_r_a),color="C0", alpha =.2)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
D_r.ppf(1/100)
# Out:
# 7.208382551150992

# %%
1/100
# Out:
# 0.01

# %%
d_r_a = d_r[d_r<D_r.ppf(1/100)]
d_r_a
# Out:
# array([5.2       , 5.2969697 , 5.39393939, 5.49090909, 5.58787879,
#        5.68484848, 5.78181818, 5.87878788, 5.97575758, 6.07272727,
#        6.16969697, 6.26666667, 6.36363636, 6.46060606, 6.55757576,
#        6.65454545, 6.75151515, 6.84848485, 6.94545455, 7.04242424,
#        7.13939394])

# %%
d_r[d_r<6.2] #Area below alpha
# Out:
# array([5.2       , 5.2969697 , 5.39393939, 5.49090909, 5.58787879,
#        5.68484848, 5.78181818, 5.87878788, 5.97575758, 6.07272727,
#        6.16969697])

# %%
plt.close('all')
plt.plot(D_r.cdf(d_r))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataframe
# Out:
#       Distribution Center Product Offering  Generation      SKU  ASP Group  \
# 0                   ALPHA                A           2  SKU-A-2          1
# 1                   ALPHA                B           2  SKU-B-2          1
# 2                   ALPHA                C           1  SKU-C-1          3
# 3                   ALPHA                C           2  SKU-C-2          4
# 4                   ALPHA                F           1  SKU-F-1          6
# ...                   ...              ...         ...      ...        ...
# 26109             EPSILON                V           4  SKU-V-4         18
# 26110             EPSILON                V           5  SKU-V-5         19
# 26111             EPSILON                W           4  SKU-W-4         21
# 26112             EPSILON                W           5  SKU-W-5         22
# 26113             EPSILON                X           5  SKU-X-5         18
#
#        Week  Forecasted Demand  Customer Orders
# 0         1               8949            11146
# 1         1              11146             3503
# 2         1               1274             5892
# 3         1              20717             3185
# 4         1              24522             6529
# ...     ...                ...              ...
# 26109   187              35159             3822
# 26110   187              13439            10987
# 26111   187              37357             5414
# 26112   187             130382            35350
# 26113   187              30860            24841
#
# [26114 rows x 8 columns]

# %%
newDF = dataframe.copy(deep=True)
newDF.drop(['Distribution Center','Product Offering','Generation','ASP Group'],axis=1,inplace=True)

# %%
meanDF = newDF.groupby(['SKU','Week'])[['Customer Orders', 'Forecasted Demand']].mean()
stdDF = newDF.groupby(['SKU','Week'])[['Customer Orders', 'Forecasted Demand']].std()

# %%
meanDF
# Out:
#               Customer Orders  Forecasted Demand
# SKU     Week
# SKU-A-2 1             7006.25           30828.00
#         2            12062.50           38591.00
#         3            10032.00           43893.25
#         4            12241.50           43033.25
#         5            18511.00           52679.25
# ...                       ...                ...
# SKU-Y-5 183          11943.00           93153.00
#         184         234076.00           50159.00
#         185         127389.00           78822.00
#         186         146497.00           69268.00
#         187         157643.00          100318.00
#
# [7421 rows x 2 columns]

# %%
stdDF
# Out:
#               Customer Orders  Forecasted Demand
# SKU     Week
# SKU-A-2 1         3035.084334       21998.246339
#         2         5760.913845       27494.053878
#         3         2833.734050       36555.889333
#         4         6560.435275       37789.756781
#         5        12781.968576       57937.831005
# ...                       ...                ...
# SKU-Y-5 183               NaN                NaN
#         184               NaN                NaN
#         185               NaN                NaN
#         186               NaN                NaN
#         187               NaN                NaN
#
# [7421 rows x 2 columns]

# %%
meanDF.rename(columns={'Customer Orders': 'meanCOs', 'Forecasted Demand': 'meanFDs'}, inplace=True)
stdDF.rename(columns={'Customer Orders': 'stdCOs', 'Forecasted Demand': 'stdFDs'}, inplace=True)

# %%
meanDF
# Out:
#                 meanCOs    meanFDs
# SKU     Week
# SKU-A-2 1       7006.25   30828.00
#         2      12062.50   38591.00
#         3      10032.00   43893.25
#         4      12241.50   43033.25
#         5      18511.00   52679.25
# ...                 ...        ...
# SKU-Y-5 183    11943.00   93153.00
#         184   234076.00   50159.00
#         185   127389.00   78822.00
#         186   146497.00   69268.00
#         187   157643.00  100318.00
#
# [7421 rows x 2 columns]

# %%
stdDF
# Out:
#                     stdCOs        stdFDs
# SKU     Week
# SKU-A-2 1      3035.084334  21998.246339
#         2      5760.913845  27494.053878
#         3      2833.734050  36555.889333
#         4      6560.435275  37789.756781
#         5     12781.968576  57937.831005
# ...                    ...           ...
# SKU-Y-5 183            NaN           NaN
#         184            NaN           NaN
#         185            NaN           NaN
#         186            NaN           NaN
#         187            NaN           NaN
#
# [7421 rows x 2 columns]

# %%
newDF = meanDF.join(stdDF)
newDF
# Out:
#                 meanCOs    meanFDs        stdCOs        stdFDs
# SKU     Week
# SKU-A-2 1       7006.25   30828.00   3035.084334  21998.246339
#         2      12062.50   38591.00   5760.913845  27494.053878
#         3      10032.00   43893.25   2833.734050  36555.889333
#         4      12241.50   43033.25   6560.435275  37789.756781
#         5      18511.00   52679.25  12781.968576  57937.831005
# ...                 ...        ...           ...           ...
# SKU-Y-5 183    11943.00   93153.00           NaN           NaN
#         184   234076.00   50159.00           NaN           NaN
#         185   127389.00   78822.00           NaN           NaN
#         186   146497.00   69268.00           NaN           NaN
#         187   157643.00  100318.00           NaN           NaN
#
# [7421 rows x 4 columns]

# %%
newDF['meanCOs'].mean()
# Out:
# 11722.555890940115

# %%
newDF['stdCOs'].mean()
# Out:
# 10850.319737155334

# %%
# newDF

# %%
pd.set_option('display.max_rows', None)

# %%
newDF.loc[newDF.first_valid_index()]
# Out:
# meanCOs     7006.250000
# meanFDs    30828.000000
# stdCOs      3035.084334
# stdFDs     21998.246339
# Name: (SKU-A-2, 1), dtype: float64

# %%
testDF = newDF.copy(deep=True)

# %%
testDF = testDF.reset_index()

# %%
testDF = testDF.loc[testDF['SKU'] == 'SKU-C-2']

# %%
# # testDF.reset_index(inplace=True)
# testDF.drop(['SKU'],axis=1,inplace=True)
# testDF

# %%
# testDF is for SKU-C-2
# testDF contains SKU level weekly average CO, standard deviation of COs and average FDs over a period of 116 weeks.

# %%
plt.close('all')
num="Forecasts vs Actuals"
if plt.fignum_exists(num):plt.close(num)
fig,ax = plt.subplots(num=num)
x = testDF['Week']
y = testDF['meanCOs']
ax.plot(x,y,marker="o",lw=.2,alpha=0.5,color="red")
ax.plot(x,testDF['meanFDs'],marker=".",lw=0.8,alpha=0.5,color="cyan")
ax.set_ylabel("Order Counts")
ax.set_xlabel("Week")
# Out:
# Text(0.5, 0, 'Week')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
testDF['Faccuracy']  = testDF['meanFDs']/(testDF['meanFDs'] + testDF['meanCOs'])

# %%
import statsmodels.api as sm
import pylab

# %%
sm.qqplot(testDF['Faccuracy'])
pylab.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# testDF

# %%
plt.close('all')
plt.hist(testDF['Faccuracy'],bins=50,edgecolor="black",density=True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
